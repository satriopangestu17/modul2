# %%
import pandas as pd
import numpy as np

dfpok = pd.read_csv('pokemon-spawns.csv',
                 na_values = ['n.a'])

dfpok = dfpok.head(1001)
# dfpok['name']
dfpok
# Out:
#                     s2_id     s2_token  num       name        lat         lng  \
# 0    -9185794522947256000  8085808cc6d   13     Weedle  37.793592 -122.408721
# 1    -9185794529389707000  8085808b51d   16     Pidgey  37.794746 -122.406420
# 2    -9185794529389707000  8085808b271   41      Zubat  37.794999 -122.404384
# 3    -9185794082713108000  808580f3587   16     Pidgey  37.795644 -122.407128
# 4    -9185794076270658000  808580f4b1d   60    Poliwag  37.795592 -122.406331
# 5    -9182922218470900000  808fb4e54b3   50    Diglett  37.301129 -122.048453
# 6    -9182922220618383000  808fb4e4ea1   23      Ekans  37.300757 -122.045701
# 7    -9182922126129103000  808fb4faf4d   41      Zubat  37.303463 -122.048187
# 8    -9182982474714579000  808f7e1799d   46      Paras  37.759467 -122.426242
# 9    -9182982313653305000  808f7e3d705   41      Zubat  37.759499 -122.423233
# 10   -9182982313653305000  808f7e3d12d   25    Pikachu  37.759913 -122.422614
# ...

# %%
import pandas as pd
import numpy as np
import folium


# latitude = []
# for i in range(len(dfpok['lat'])):
#     latitude.append(dfpok['lat'])
# latitude

# long = []
# for i in range(len(dfpok['lng'])):
#     long.append(dfpok['lng'])
# long

# nomor = []
# for i in range(len(dfpok['num'])):
#     nomor.append(dfpok['num'])
# nomor

# nama = []
# for i in range(len(dfpok['name'])):
#     nama.append(dfpok['name'])
# nama

# for i in range (len(dfpok['name'])):
#     map = folium.Map(
#     location = [long[i], latitude[i]],
#         tiles= 'OpenStreetMap',
#     zoom_start=17)   ## ga bisa kalau map

number = dfpok['num']


map = folium.Map(
    location = [dfpok['lat'][0], dfpok['lng'][0]], tiles= 'OpenStreetMap',
    zoom_start=17)


    
for i in range(len(dfpok['name'])):
    icon_url = f'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/back/{number[i]}.png'
    icon = folium.features.CustomIcon(icon_url, icon_size=(60, 70))
    folium.Marker(
    location = [dfpok['lat'][i], dfpok['lng'][i]], 
    popup = dfpok['name'][i], # gabisa kalau nama[i]   jadi kalau yang sudah ada didalam column ga perlu dibikin di list lagi
    tooltip = f'<img widht="200px" src="https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/back/{number[i]}.png"></img>',
    icon= icon).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import pandas as pd
import numpy as np
import folium


# latitude = []
# for i in range(len(dfpok['lat'])):
#     latitude.append(dfpok['lat'])
# latitude

# long = []
# for i in range(len(dfpok['lng'])):
#     long.append(dfpok['lng'])
# long

# nomor = []
# for i in range(len(dfpok['num'])):
#     nomor.append(dfpok['num'])
# nomor

# nama = []
# for i in range(len(dfpok['name'])):
#     nama.append(dfpok['name'])
# nama

# for i in range (len(dfpok['name'])):
#     map = folium.Map(
#     location = [long[i], latitude[i]],
#         tiles= 'OpenStreetMap',
#     zoom_start=17)   ## ga bisa kalau map


pokemon = input('poke name: ').capitalize()

pokemonlat = dfpok['lat'][dfpok['name'] == pokemon].tolist()
pokemonlng = dfpok['lng'][dfpok['name'] == pokemon].tolist()

# lok = [pokemonlat, pokemonlng]

number = dfpok['num'][dfpok['name'] == pokemon].tolist()
# number = number.set_index(np.arange(0,len(df)))
lok
# number
# len(pokemonlat)
number[0]
# Out:
# poke name: pikachu
# 25

# %%
map = folium.Map(
    location = [dfpok['lat'][0], dfpok['lng'][0]], tiles= 'OpenStreetMap',
    zoom_start=17)


    
for i in range(len(pokemonlat)):
    icon_url = f'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/back/{number[i]}.png'
    icon = folium.features.CustomIcon(icon_url, icon_size=(60, 70))
    folium.Marker(
    location = [pokemonlat[i], pokemonlng[i]], 
    popup = dfpok['name'][i], # gabisa kalau nama[i]   jadi kalau yang sudah ada didalam column ga perlu dibikin di list lagi
    tooltip = f'<img widht="200px" src="https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/back/{number[i]}.png"></img>',
    icon= icon).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
